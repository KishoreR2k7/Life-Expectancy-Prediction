# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Cleaned Data.csv')
df.head()
# Out:
#    Unnamed: 0  Year  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0           0  2015             65.0            263.0             62     0.01
# 1           1  2014             59.9            271.0             64     0.01
# 2           2  2013             59.9            268.0             66     0.01
# 3           3  2012             59.5            272.0             69     0.01
# 4           4  2011             59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles   BMI  ...  Country_Turkey  \
# 0               71.279624         65.0     1154  19.1  ...           False
# 1               73.523582         62.0      492  18.6  ...           False
# 2               73.219243         64.0      430  18.1  ...           False
# 3               78.184215         67.0     2787  17.6  ...           False
# 4                7.097109         68.0     3013  17.2  ...           False
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI',
#        ...
#        'Country_Turkey', 'Country_Turkmenistan', 'Country_Uganda',
#        'Country_Ukraine', 'Country_Uruguay', 'Country_Uzbekistan',
#        'Country_Vanuatu', 'Country_Zambia', 'Country_Zimbabwe',
#        'Status_Developing'],
#       dtype='object', length=154)

# %%
sns.kdeplot(x=df['Life expectancy'],fill=True)
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Density'>

# %%
features=df[["Schooling","Income composition of resources","BMI","Alcohol","Adult Mortality","HIV/AIDS","thinness  1-19 years","Life expectancy"]]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(features.corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
features=["Schooling", "Income composition of resources", "BMI"]

# %%
for col in features:
    plt.figure(figsize=(6,4))
    sns.kdeplot(df[col],fill=True)
    plt.title(f"Distribution of {col}")
    plt.show()
